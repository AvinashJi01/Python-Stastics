# %% [markdown]
# 1ST Exercise
# Dta Representation And Intraction : Basic

# %%
# Creating Series From Array

# %%
import pandas as pd

# %%
import numpy as np

# %%
info=np.array(['p','a','n','d','a','s'])

# %%
a=pd.Series(info)

# %%
print(a)
# Out:
# 0    p
# 1    a
# 2    n
# 3    d
# 4    a
# 5    s
# dtype: object

# %%
#Create Data Frame Using List

# %%
x=['Python','Pandas']

# %%
df=pd.DataFrame(x)

# %%
print(df)
# Out:
#         0
# 0  Python
# 1  Pandas

# %%
# pandas Series.map()

# %%
#1st Example this is use to change any one value

# %%
a=pd.Series(['JAVA','C++','C',np.nan])

# %%
a.map({'JAVA':'CORE'})
# Out:
# 0    CORE
# 1     NaN
# 2     NaN
# 3     NaN
# dtype: object

# %%
#2nd Example this is use to some add in all data value

# %%
a=pd.Series(['JAVA','C++','C',np.nan])

# %%
a.map({'JAVA':'CORE'})

# %%
a.map('i like{}'.format,na_action='ignore')
# Out:
# 0    i likeJAVA
# 1     i likeC++
# 2       i likeC
# 3           NaN
# dtype: object

# %%
# pandas Series.to_frame() (this function is use to  convert the series object to the data fram)

# %%
#1st Example

# %%
s=pd.Series(["a","b","c"],name="vals")

# %%
s.to_frame()
# Out:
#   vals
# 0    a
# 1    b
# 2    c

# %%
#2nd Example

# %%
import matplotlib.pyplot as plt

# %%
emp=['Avi','Manan','Vaibhav','Vivek']

# %%
id=[102,105,107,109]

# %%
emp_series=pd.Series(emp)

# %%
id_series=pd.Series(id)

# %%
frame={'EMP':emp_series,'ID':id_series}

# %%
result=pd.DataFrame(frame)

# %%
print(result)
# Out:
#        EMP   ID
# 0      Avi  102
# 1    Manan  105
# 2  Vaibhav  107
# 3    Vivek  109

# %% [markdown]
# 2ND Exercise
# Dta Representation And Intraction : Advanced

# %%
#Create An Empty Data Frame

# %%
df=pd.DataFrame()

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Create A DataFrame Using List or nd Arrays

# %%
inf1={'ID':[101,102,103,104],'Employee':['AVINASH','NEHA','SUMIT','HARSH']}

# %%
df=pd.DataFrame(inf1)

# %%
print(df)
# Out:
#     ID Employee
# 0  101  AVINASH
# 1  102     NEHA
# 2  103    SUMIT
# 3  104    HARSH

# %%
#Create DtaFrame Using Dict of Series

# %%
inf2={'one':pd.Series([1,2,3,4,5,],index=['p','e','i','o','u']),'two':pd.Series([1,2,3,4,5,6,7],index=['a','e','i','o','u','v','w'])}

# %%
d1=pd.DataFrame(inf2)

# %%
print(d1)
# Out:
#    one  two
# a  NaN  1.0
# e  2.0  2.0
# i  3.0  3.0
# o  4.0  4.0
# p  1.0  NaN
# u  5.0  5.0
# v  NaN  6.0
# w  NaN  7.0

# %%
#Selection By Lavel

# %%
import pandas as pd

# %%
info3={'one':pd.Series([1,2,3,4,5],index=['a','b','c','d','e']),'two':pd.Series([1,2,3,4,5,6,7],index=['a','b','c','d','e','f','g'])}

# %%
df=pd.DataFrame(info3)

# %%
print(df.loc['b'])
# Out:
# one    2.0
# two    2.0
# Name: b, dtype: float64

# %%
#Selection By Integar Location

# %%
info3={'one':pd.Series([1,2,3,4,5],index=['a','b','c','d','e']),'two':pd.Series([1,2,3,4,5,6,7],index=['a','b','c','d','e','f','g'])}

# %%
df=pd.DataFrame(info3)

# %%
print(df.iloc[3])
# Out:
# one    4.0
# two    4.0
# Name: d, dtype: float64

# %%
#Slice Rows

# %%
info3={'one':pd.Series([1,2,3,4,5],index=['a','b','c','d','e']),'two':pd.Series([1,2,3,4,5,6,7],index=['a','b','c','d','e','f','g'])}

# %%
df=pd.DataFrame(info3)

# %%
print(df[2:5])
# Out:
#    one  two
# c  3.0    3
# d  4.0    4
# e  5.0    5

# %%
#Addition Of Rows

# %%
s=pd.DataFrame([[7,8],[9,10]],columns=['x','y'])

# %%
s1=pd.DataFrame([[11,12],[13,14]],columns=['x','y'])

# %%
s=s.append(s1)
# Out:
# <ipython-input-40-4c2cd6223545>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s=s.append(s1)

# %%
print(s)
# Out:
#     x   y
# 0   7   8
# 1   9  10
# 0  11  12
# 1  13  14

# %%
#Deletation Of Rows

# %%
a_info4=pd.DataFrame([[4,5],[6,7]],columns=['x','y'])

# %%
b_info4=pd.DataFrame([[8,9],[10,11]],columns=['x','y'])

# %%
a_info4=a_info4.append(b_info4)
# Out:
# <ipython-input-57-e4d04066d592>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   a_info4=a_info4.append(b_info4)

# %%
a_info4=a_info4.drop(0)

# %%
print(a_info4)
# Out:
#     x   y
# 1   6   7
# 1  10  11

# %%
print(b_info4)
# Out:
#     x   y
# 0   8   9
# 1  10  11
